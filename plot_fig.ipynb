# %%
from all_fn import *

# Parameters setup
model_name = "2D_q=6_clock"
symm = 1#symm#
dcut = 10#dcut#
Lmax = 200#Lmax#
unit_size = 1#unit_size#

model = Model(model_name, symm)
T     = model.Tc[0]
    
HOTRG = Hotrg()
HOTRG.dcut = dcut
HOTRG.trgstep = int(np.floor(np.log2(Lmax/unit_size)))
Ls = unit_size * 2**np.arange(0, HOTRG.trgstep+1)

print("{}, symm={}, D={}".format(model.name, model.symm, HOTRG.dcut))
print("T = ", T)
print("L = ", Ls)

# Folders creation
prefix = f"{model.name}{'_symm' if model.symm else ''}/"
Folder_T0    = prefix + f"T0_tensor/"
Folder_Norms = prefix + f"Norms/"
makeFolder(Folder_T0)
makeFolder(Folder_Norms)

for L in Ls:
    if L == unit_size:
        T0 = model.T0_1x1(T)
        T0 = ExactCon.contract_LxL([T0]*unit_size**2, unit_size)
        Norm = max([block.Abs().Max().item() for block in T0.get_blocks()])
        T0 /= Norm                
        Norms = [Norm]

    else:
        T0, Uy, Ny, Sy = HOTRG.update_pure(T0, T0, "y", HOTRG.dcut, "Abs_Max")
        del Uy, Sy
        T0, Ux, Nx, Sx = HOTRG.update_pure(T0, T0, "x", HOTRG.dcut, "Abs_Max")
        Norms = np.append(Norms, Ny**2 * Nx)
        del Ux, Sx, Ny, Nx

    T0.Save(Folder_T0 + "T0_T{}_L{}_D{}_US{}_{}".format(T,L,HOTRG.dcut,unit_size,model.name))
    np.save(Folder_Norms + "Norms_T{}_L{}_D{}_US{}_{}.npy".format(T,L,HOTRG.dcut,unit_size,model.name), Norms)

    print("done L={}".format(L))

print("done")
# Out:
# 2D_q=6_clock, symm=1, D=10
# T =  0.69014
# L =  [  1   2   4   8  16  32  64 128]
# done L=1
# done L=2
# done L=4
# done L=8
# done L=16
# done L=32
# done L=64
# done L=128
# done

# %%
! conda install pandas matplotlib scipy pathlib -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.3.1
#     latest version: 26.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/chansh/miniconda3/envs/cytnx_Feb_2026
#
#   added / updated specs:
#     - matplotlib
#     - pandas
#     - pathlib
#     - scipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.15.3          |       hb03c661_0         571 KB  conda-forge
#     blas-1.1                   |         openblas           1 KB  conda-forge
#     brotli-1.2.0               |       hed03a55_1          20 KB  conda-forge
#     brotli-bin-1.2.0           |       hb03c661_1          21 KB  conda-forge
#     brotli-python-1.0.9        |   py38hfa26641_8         353 KB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
#     cffi-1.17.0                |   py38heb5c249_0         235 KB  conda-forge
#     charset-normalizer-3.4.0   |     pyhd8ed1ab_0          46 KB  conda-forge
#     contourpy-1.1.1            |   py38h7f3f72f_1         217 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_0          13 KB  conda-forge
#     dbus-1.16.2                |       h24cb091_1         437 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |       hc364b38_1           4 KB  conda-forge
#     fonttools-4.53.1           |   py38h2019614_0         2.2 MB  conda-forge
#     glib-2.86.3                |       h5192d8d_0         598 KB  conda-forge
#     glib-tools-2.86.3          |       hf516916_0         114 KB  conda-forge
#     h2-4.1.0                   |     pyhd8ed1ab_0          46 KB  conda-forge
#     hpack-4.0.0                |     pyh9f0ad1d_0          25 KB  conda-forge
#     hyperframe-6.0.1           |     pyhd8ed1ab_0          14 KB  conda-forge
#     idna-3.10                  |     pyhd8ed1ab_0          49 KB  conda-forge
#     importlib-resources-6.4.5  |     pyhd8ed1ab_0           9 KB  conda-forge
#     importlib_resources-6.4.5  |     pyhd8ed1ab_0          32 KB  conda-forge
#     kiwisolver-1.4.5           |   py38h7f3f72f_1          72 KB  conda-forge
#     lcms2-2.18                 |       h0c24ade_0         244 KB  conda-forge
#     libblas-3.9.0              |1_h86c2bf4_netlib         199 KB  conda-forge
#     libbrotlicommon-1.2.0      |       hb03c661_1          78 KB  conda-forge
#     libbrotlidec-1.2.0         |       hb03c661_1          34 KB  conda-forge
#     libbrotlienc-1.2.0         |       hb03c661_1         291 KB  conda-forge
#     libcap-2.77                |       h3ff7636_0         119 KB  conda-forge
#     libcblas-3.9.0             |13_h8e06fc2_netlib          53 KB  conda-forge
#     libclang-cpp21.1-21.1.8    |default_h99862b1_3        20.1 MB  conda-forge
#     libclang13-21.1.8          |default_h746c552_3        11.8 MB  conda-forge
#     libcurl-8.18.0             |       h4e3cde8_0         452 KB  conda-forge
#     libegl-1.7.0               |       ha4b6fd6_2          44 KB  conda-forge
#     libflac-1.5.0              |       he200343_1         415 KB  conda-forge
#     libfreetype-2.14.1         |       ha770c72_0           7 KB  conda-forge
#     libgfortran-ng-15.2.0      |      h69a702a_17          27 KB  conda-forge
#     libglib-2.86.3             |       h6548e54_0         3.8 MB  conda-forge
#     liblapack-3.9.0            |13_h8876d29_netlib         2.7 MB  conda-forge
#     libllvm21-21.1.8           |       hf7376ad_0        42.3 MB  conda-forge
#     libopus-1.6.1              |       h280c20c_0         317 KB  conda-forge
#     libpng-1.6.55              |       h421ea60_0         310 KB  conda-forge
#     libpq-18.1                 |       h5c52fec_2         2.6 MB  conda-forge
#     libsndfile-1.2.2           |       hc7d488a_2         347 KB  conda-forge
#     libsystemd0-259.1          |       h6569c3e_0         511 KB  conda-forge
#     libxkbcommon-1.13.1        |       hca5e8e5_0         818 KB  conda-forge
#     libxml2-2.15.1             |       h26afc86_0          44 KB  conda-forge
#     matplotlib-3.7.3           |   py38h578d9bd_0           8 KB  conda-forge
#     matplotlib-base-3.7.3      |   py38h58ed7fa_0         6.4 MB  conda-forge
#     nss-3.118                  |       h445c969_0         2.0 MB  conda-forge
#     packaging-26.0             |     pyhcf101f3_0          70 KB  conda-forge
#     pandas-2.0.3               |   py38h01efb38_1        11.8 MB  conda-forge
#     pathlib-1.0.1              |   py38h578d9bd_7           5 KB  conda-forge
#     pillow-10.4.0              |   py38h2bc05a7_0        40.3 MB  conda-forge
#     platformdirs-4.3.6         |     pyhd8ed1ab_0          20 KB  conda-forge
#     ply-3.11                   |     pyhd8ed1ab_2          48 KB  conda-forge
#     pooch-1.8.2                |     pyhd8ed1ab_0          53 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     pulseaudio-client-17.0     |       h9a6aba3_3         733 KB  conda-forge
#     pycparser-2.22             |     pyhd8ed1ab_0         103 KB  conda-forge
#     pyparsing-3.1.4            |     pyhd8ed1ab_0          88 KB  conda-forge
#     pyqt-5.15.9                |   py38hffdaa6c_5         5.0 MB  conda-forge
#     pyqt5-sip-12.12.2          |   py38h17151c0_5          83 KB  conda-forge
#     pysocks-1.7.1              |     pyha2e5f31_6          19 KB  conda-forge
#     python-dateutil-2.9.0      |     pyhd8ed1ab_0         218 KB  conda-forge
#     python-tzdata-2024.2       |     pyhd8ed1ab_0         139 KB  conda-forge
#     pytz-2024.2                |     pyhd8ed1ab_0         183 KB  conda-forge
#     requests-2.32.3            |     pyhd8ed1ab_0          57 KB  conda-forge
#     scipy-1.10.1               |   py38h32ae08f_1        22.4 MB
#     sip-6.7.12                 |   py38h17151c0_0         477 KB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     toml-0.10.2                |     pyhd8ed1ab_0          18 KB  conda-forge
#     tomli-2.0.2                |     pyhd8ed1ab_0          18 KB  conda-forge
#     tornado-6.4.1              |   py38hfb59056_0         627 KB  conda-forge
#     unicodedata2-15.1.0        |   py38h01eb140_0         365 KB  conda-forge
#     urllib3-2.2.3              |     pyhd8ed1ab_0          96 KB  conda-forge
#     xorg-libx11-1.8.13         |       he1eb515_0         820 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb03c661_1          15 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb03c661_1          20 KB  conda-forge
#     xorg-libxext-1.3.7         |       hb03c661_0          49 KB  conda-forge
#     xorg-libxxf86vm-1.1.7      |       hb03c661_0          18 KB  conda-forge
#     zipp-3.21.0                |     pyhd8ed1ab_0          21 KB  conda-forge
#     zstandard-0.19.0           |   py38h0a891b7_0         671 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       185.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.15.3-hb03c661_0
#   attr               conda-forge/linux-64::attr-2.5.2-h39aace5_0
#   blas               conda-forge/linux-64::blas-1.1-openblas
#   brotli             conda-forge/linux-64::brotli-1.2.0-hed03a55_1
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.2.0-hb03c661_1
#   brotli-python      conda-forge/linux-64::brotli-python-1.0.9-py38hfa26641_8
#   cairo              conda-forge/linux-64::cairo-1.18.4-h3394656_0
#   certifi            conda-forge/noarch::certifi-2024.8.30-pyhd8ed1ab_0
#   cffi               conda-forge/linux-64::cffi-1.17.0-py38heb5c249_0
#   charset-normalizer conda-forge/noarch::charset-normalizer-3.4.0-pyhd8ed1ab_0
#   contourpy          conda-forge/linux-64::contourpy-1.1.1-py38h7f3f72f_1
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   cyrus-sasl         conda-forge/linux-64::cyrus-sasl-2.1.28-hd9c7081_0
#   dbus               conda-forge/linux-64::dbus-1.16.2-h24cb091_1
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-hc364b38_1
#   fonttools          conda-forge/linux-64::fonttools-4.53.1-py38h2019614_0
#   freetype           conda-forge/linux-64::freetype-2.14.1-ha770c72_0
#   glib               conda-forge/linux-64::glib-2.86.3-h5192d8d_0
#   glib-tools         conda-forge/linux-64::glib-tools-2.86.3-hf516916_0
#   graphite2          conda-forge/linux-64::graphite2-1.3.14-hecca717_2
#   gst-plugins-base   conda-forge/linux-64::gst-plugins-base-1.24.11-h651a532_0
#   gstreamer          conda-forge/linux-64::gstreamer-1.24.11-hc37bda9_0
#   h2                 conda-forge/noarch::h2-4.1.0-pyhd8ed1ab_0
#   harfbuzz           conda-forge/linux-64::harfbuzz-12.2.0-h15599e2_0
#   hpack              conda-forge/noarch::hpack-4.0.0-pyh9f0ad1d_0
#   hyperframe         conda-forge/noarch::hyperframe-6.0.1-pyhd8ed1ab_0
#   idna               conda-forge/noarch::idna-3.10-pyhd8ed1ab_0
#   importlib-resourc~ conda-forge/noarch::importlib-resources-6.4.5-pyhd8ed1ab_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-6.4.5-pyhd8ed1ab_0
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.5-py38h7f3f72f_1
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   lcms2              conda-forge/linux-64::lcms2-2.18-h0c24ade_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h0aef613_1
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.2.0-hb03c661_1
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.2.0-hb03c661_1
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.2.0-hb03c661_1
#   libcap             conda-forge/linux-64::libcap-2.77-h3ff7636_0
#   libclang-cpp21.1   conda-forge/linux-64::libclang-cpp21.1-21.1.8-default_h99862b1_3
#   libclang13         conda-forge/linux-64::libclang13-21.1.8-default_h746c552_3
#   libcups            conda-forge/linux-64::libcups-2.3.3-hb8b1518_5
#   libdeflate         conda-forge/linux-64::libdeflate-1.25-h17f619e_0
#   libdrm             conda-forge/linux-64::libdrm-2.4.125-hb03c661_1
#   libegl             conda-forge/linux-64::libegl-1.7.0-ha4b6fd6_2
#   libevent           conda-forge/linux-64::libevent-2.1.12-hf998b51_1
#   libflac            conda-forge/linux-64::libflac-1.5.0-he200343_1
#   libfreetype        conda-forge/linux-64::libfreetype-2.14.1-ha770c72_0
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.14.1-h73754d4_0
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-15.2.0-h69a702a_17
#   libgl              conda-forge/linux-64::libgl-1.7.0-ha4b6fd6_2
#   libglib            conda-forge/linux-64::libglib-2.86.3-h6548e54_0
#   libglvnd           conda-forge/linux-64::libglvnd-1.7.0-ha4b6fd6_2
#   libglx             conda-forge/linux-64::libglx-1.7.0-ha4b6fd6_2
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.1.2-hb03c661_0
#   libllvm21          conda-forge/linux-64::libllvm21-21.1.8-hf7376ad_0
#   libntlm            conda-forge/linux-64::libntlm-1.8-hb9d3cd8_0
#   libogg             conda-forge/linux-64::libogg-1.3.5-hd0c01bc_1
#   libopus            conda-forge/linux-64::libopus-1.6.1-h280c20c_0
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.18-hb9d3cd8_0
#   libpng             conda-forge/linux-64::libpng-1.6.55-h421ea60_0
#   libpq              conda-forge/linux-64::libpq-18.1-h5c52fec_2
#   libsndfile         conda-forge/linux-64::libsndfile-1.2.2-hc7d488a_2
#   libsystemd0        conda-forge/linux-64::libsystemd0-259.1-h6569c3e_0
#   libtiff            conda-forge/linux-64::libtiff-4.7.1-h9d88235_1
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h54a6638_2
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.6.0-hd42ef1d_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.13.1-hca5e8e5_0
#   libxml2            conda-forge/linux-64::libxml2-2.15.1-h26afc86_0
#   libxml2-16         conda-forge/linux-64::libxml2-16-2.15.1-ha9997c6_0
#   matplotlib         conda-forge/linux-64::matplotlib-3.7.3-py38h578d9bd_0
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.7.3-py38h58ed7fa_0
#   mpg123             conda-forge/linux-64::mpg123-1.32.9-hc50e24c_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   nspr               conda-forge/linux-64::nspr-4.38-h29cc59b_0
#   nss                conda-forge/linux-64::nss-3.118-h445c969_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.4-h55fea9a_0
#   openldap           conda-forge/linux-64::openldap-2.6.10-he970967_0
#   packaging          conda-forge/noarch::packaging-26.0-pyhcf101f3_0
#   pandas             conda-forge/linux-64::pandas-2.0.3-py38h01efb38_1
#   pathlib            conda-forge/linux-64::pathlib-1.0.1-py38h578d9bd_7
#   pillow             conda-forge/linux-64::pillow-10.4.0-py38h2bc05a7_0
#   pixman             conda-forge/linux-64::pixman-0.46.4-h54a6638_1
#   platformdirs       conda-forge/noarch::platformdirs-4.3.6-pyhd8ed1ab_0
#   ply                conda-forge/noarch::ply-3.11-pyhd8ed1ab_2
#   pooch              conda-forge/noarch::pooch-1.8.2-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pulseaudio-client  conda-forge/linux-64::pulseaudio-client-17.0-h9a6aba3_3
#   pycparser          conda-forge/noarch::pycparser-2.22-pyhd8ed1ab_0
#   pyparsing          conda-forge/noarch::pyparsing-3.1.4-pyhd8ed1ab_0
#   pyqt               conda-forge/linux-64::pyqt-5.15.9-py38hffdaa6c_5
#   pyqt5-sip          conda-forge/linux-64::pyqt5-sip-12.12.2-py38h17151c0_5
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0-pyhd8ed1ab_0
#   python-tzdata      conda-forge/noarch::python-tzdata-2024.2-pyhd8ed1ab_0
#   pytz               conda-forge/noarch::pytz-2024.2-pyhd8ed1ab_0
#   qt-main            conda-forge/linux-64::qt-main-5.15.15-h3c3fd16_6
#   requests           conda-forge/noarch::requests-2.32.3-pyhd8ed1ab_0
#   scipy              pkgs/main/linux-64::scipy-1.10.1-py38h32ae08f_1
#   sip                conda-forge/linux-64::sip-6.7.12-py38h17151c0_0
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   toml               conda-forge/noarch::toml-0.10.2-pyhd8ed1ab_0
#   tomli              conda-forge/noarch::tomli-2.0.2-pyhd8ed1ab_0
#   tornado            conda-forge/linux-64::tornado-6.4.1-py38hfb59056_0
#   unicodedata2       conda-forge/linux-64::unicodedata2-15.1.0-py38h01eb140_0
#   urllib3            conda-forge/noarch::urllib3-2.2.3-pyhd8ed1ab_0
#   xcb-util           conda-forge/linux-64::xcb-util-0.4.1-h4f16b4b_2
#   xcb-util-image     conda-forge/linux-64::xcb-util-image-0.4.0-hb711507_2
#   xcb-util-keysyms   conda-forge/linux-64::xcb-util-keysyms-0.4.1-hb711507_0
#   xcb-util-renderut~ conda-forge/linux-64::xcb-util-renderutil-0.3.10-hb711507_0
#   xcb-util-wm        conda-forge/linux-64::xcb-util-wm-0.4.2-hb711507_0
#   xkeyboard-config   conda-forge/linux-64::xkeyboard-config-2.46-hb03c661_0
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.6-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.13-he1eb515_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb03c661_1
#   xorg-libxdamage    conda-forge/linux-64::xorg-libxdamage-1.1.6-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb03c661_1
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.7-hb03c661_0
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-6.0.2-hb03c661_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.12-hb9d3cd8_0
#   xorg-libxshmfence  conda-forge/linux-64::xorg-libxshmfence-1.3.3-hb9d3cd8_0
#   xorg-libxxf86vm    conda-forge/linux-64::xorg-libxxf86vm-1.1.7-hb03c661_0
#   zipp               conda-forge/noarch::zipp-3.21.0-pyhd8ed1ab_0
#   zstandard          conda-forge/linux-64::zstandard-0.19.0-py38h0a891b7_0
#
# The following packages will be DOWNGRADED:
#
#   krb5                                    1.22.2-ha1258a1_0 --> 1.21.3-h659f571_0
#   libblas                          3.11.0-7_hc00574d_netlib --> 3.9.0-1_h86c2bf4_netlib
#   libcblas                         3.11.0-7_h8e06fc2_netlib --> 3.9.0-13_h8e06fc2_netlib
#   libcurl                                 8.18.0-hcf29cc6_1 --> 8.18.0-h4e3cde8_0
#   liblapack                        3.11.0-7_h8876d29_netlib --> 3.9.0-13_h8876d29_netlib
#
#
#
# Downloading and Extracting Packages:
# libllvm21-21.1.8     | 42.3 MB   |                                       |   0%
# pillow-10.4.0        | 40.3 MB   |                                       |   0%
#
# scipy-1.10.1         | 22.4 MB   |                                       |   0%
#
#
# libclang-cpp21.1-21. | 20.1 MB   |                                       |   0%
#
#
#
# pandas-2.0.3         | 11.8 MB   |                                       |   0%
#
#
#
#
# libclang13-21.1.8    | 11.8 MB   |                                       |   0%
#
#
#
#
#
# matplotlib-base-3.7. | 6.4 MB    |                                       |   0%
#
#
#
#
#
#
# pyqt-5.15.9          | 5.0 MB    |                                       |   0%
#
#
#
#
#
#
#
# libglib-2.86.3       | 3.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 2.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libpq-18.1           | 2.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# fonttools-4.53.1     | 2.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# nss-3.118            | 2.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.13   | 820 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxkbcommon-1.13.1  | 818 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pulseaudio-client-17 | 733 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.19.0     | 671 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.4.1        | 627 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.86.3          | 598 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# alsa-lib-1.2.15.3    | 571 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsystemd0-259.1    | 511 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 477 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.18.0       | 452 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm21-21.1.8     | 42.3 MB   |                                       |   0% [A
#
#
# libclang-cpp21.1-21. | 20.1 MB   |                                       |   0%
#
#
#
# libllvm21-21.1.8     | 42.3 MB   | ##2                                   |   6%
#
#
# libclang-cpp21.1-21. | 20.1 MB   | #####                                 |  14%
#
#
#
# libllvm21-21.1.8     | 42.3 MB   | ###9                                  |  11%
#
#
#
# pandas-2.0.3         | 11.8 MB   | ###########8                          |  32%
#
#
# libclang-cpp21.1-21. | 20.1 MB   | #######9                              |  21%
#
# libllvm21-21.1.8     | 42.3 MB   | ######4                               |  17%
#
#
#
# pandas-2.0.3         | 11.8 MB   | ######################3               |  60%
#
#
# libclang-cpp21.1-21. | 20.1 MB   | #############8                        |  37%
# libllvm21-21.1.8     | 42.3 MB   | ########4                             |  23%
#
# scipy-1.10.1         | 22.4 MB   | 2                                     |   1%
#
#
#
# pandas-2.0.3         | 11.8 MB   | ############################9         |  78%
#
#
# libclang-cpp21.1-21. | 20.1 MB   | ##################4                   |  50%
# pillow-10.4.0        | 40.3 MB   | 1                                     |   0%
#
# scipy-1.10.1         | 22.4 MB   | 6                                     |   2%
#
#
#
# pandas-2.0.3         | 11.8 MB   | ###################################6  |  96%
# libllvm21-21.1.8     | 42.3 MB   | ##########3                           |  28%
#
#
# libclang-cpp21.1-21. | 20.1 MB   | ######################3               |  60%
#
#
#
# pandas-2.0.3         | 11.8 MB   | ##################################### | 100%
#
# scipy-1.10.1         | 22.4 MB   | #2                                    |   3%
# pillow-10.4.0        | 40.3 MB   | 3                                     |   1%
#
#
#
#
# libllvm21-21.1.8     | 42.3 MB   | ############                          |  33%
#
# scipy-1.10.1         | 22.4 MB   | #8                                    |   5%
#
#
# libclang-cpp21.1-21. | 20.1 MB   | #########################8            |  70%
#
#
#
#
# libclang13-21.1.8    | 11.8 MB   | ###2                                  |   9%
# pillow-10.4.0        | 40.3 MB   | 3                                     |   1%
#
# libllvm21-21.1.8     | 42.3 MB   | #############6                        |  37%
#
#
#
#
# libclang13-21.1.8    | 11.8 MB   | #######1                              |  19%
# pillow-10.4.0        | 40.3 MB   | 4                                     |   1%
#
#
# libclang-cpp21.1-21. | 20.1 MB   | ############################8         |  78%
#
# libllvm21-21.1.8     | 42.3 MB   | ###############                       |  41%
#
#
#
#
# libclang13-21.1.8    | 11.8 MB   | #########9                            |  27%
# pillow-10.4.0        | 40.3 MB   | 5                                     |   2%
#
# scipy-1.10.1         | 22.4 MB   | ###6                                  |  10%
#
#
# libllvm21-21.1.8     | 42.3 MB   | ################4                     |  44%
#
#
#
#
# libclang13-21.1.8    | 11.8 MB   | #############7                        |  37%
# pillow-10.4.0        | 40.3 MB   | 6                                     |   2%
#
# scipy-1.10.1         | 22.4 MB   | ####2                                 |  12%
#
#
#
#
# libclang13-21.1.8    | 11.8 MB   | ################7                     |  45%
#
#
# libllvm21-21.1.8     | 42.3 MB   | #################7                    |  48%
# pillow-10.4.0        | 40.3 MB   | 7                                     |   2%
#
# scipy-1.10.1         | 22.4 MB   | ####8                                 |  13%
#
#
#
#
# libclang13-21.1.8    | 11.8 MB   | ####################4                 |  55%
#
#
# libllvm21-21.1.8     | 42.3 MB   | ##################9                   |  51%
# pillow-10.4.0        | 40.3 MB   | 8                                     |   2%
#
# scipy-1.10.1         | 22.4 MB   | #####4                                |  15%
#
#
#
#
# libllvm21-21.1.8     | 42.3 MB   | ####################1                 |  54%
# pillow-10.4.0        | 40.3 MB   | 9                                     |   2%
#
# scipy-1.10.1         | 22.4 MB   | ######                                |  16%
#
#
#
#
# libclang13-21.1.8    | 11.8 MB   | ##########################9           |  73%
# libllvm21-21.1.8     | 42.3 MB   | #####################2                |  58%
#
# scipy-1.10.1         | 22.4 MB   | ######6                               |  18%
#
#
#
#
# libclang13-21.1.8    | 11.8 MB   | ##############################7       |  83%
# libllvm21-21.1.8     | 42.3 MB   | ######################3               |  60%
#
# scipy-1.10.1         | 22.4 MB   | #######4                              |  20%
#
#
#
#
# libclang13-21.1.8    | 11.8 MB   | ###################################1  |  95%
# pillow-10.4.0        | 40.3 MB   | #2                                    |   3%
#
# libllvm21-21.1.8     | 42.3 MB   | #######################4              |  63%
# pillow-10.4.0        | 40.3 MB   | #5                                    |   4%
#
# libllvm21-21.1.8     | 42.3 MB   | ########################4             |  66%
# pillow-10.4.0        | 40.3 MB   | #7                                    |   5%
#
# libllvm21-21.1.8     | 42.3 MB   | #########################4            |  69%
# pillow-10.4.0        | 40.3 MB   | ##1                                   |   6%
#
# libllvm21-21.1.8     | 42.3 MB   | ##########################4           |  71%
# pillow-10.4.0        | 40.3 MB   | ##5                                   |   7%
#
# libllvm21-21.1.8     | 42.3 MB   | ###########################4          |  74%
# pillow-10.4.0        | 40.3 MB   | ###                                   |   8%
#
# libllvm21-21.1.8     | 42.3 MB   | ############################3         |  77%
# pillow-10.4.0        | 40.3 MB   | ###6                                  |  10%
#
# libllvm21-21.1.8     | 42.3 MB   | #############################3        |  79%
# pillow-10.4.0        | 40.3 MB   | ####4                                 |  12%
#
# libllvm21-21.1.8     | 42.3 MB   | ##############################3       |  82%
# pillow-10.4.0        | 40.3 MB   | #####3                                |  14%
#
# libllvm21-21.1.8     | 42.3 MB   | ###############################2      |  84%
# pillow-10.4.0        | 40.3 MB   | ######2                               |  17%
#
# libllvm21-21.1.8     | 42.3 MB   | ################################1     |  87%
# pillow-10.4.0        | 40.3 MB   | #######3                              |  20%
#
#
#
#
# libclang13-21.1.8    | 11.8 MB   | ##################################### | 100%
#
# scipy-1.10.1         | 22.4 MB   | ########################8             |  67%
# pillow-10.4.0        | 40.3 MB   | ########2                             |  22%
#
#
# libclang-cpp21.1-21. | 20.1 MB   | ##################################### | 100%
#
#
#
#
#
# libllvm21-21.1.8     | 42.3 MB   | #################################     |  89%
#
#
#
#
#
#
# pyqt-5.15.9          | 5.0 MB    | 1                                     |   0%
#
# scipy-1.10.1         | 22.4 MB   | ##########################4           |  71%
#
#
#
#
#
# matplotlib-base-3.7. | 6.4 MB    | ####4                                 |  12%
# pillow-10.4.0        | 40.3 MB   | #########1                            |  25%
#
#
#
#
#
#
# libllvm21-21.1.8     | 42.3 MB   | #################################8    |  92%
#
#
#
#
#
#
# scipy-1.10.1         | 22.4 MB   | ###########################8          |  75%
# pillow-10.4.0        | 40.3 MB   | #########9                            |  27%
#
#
#
#
#
#
# pyqt-5.15.9          | 5.0 MB    | ######8                               |  18%
#
#
#
#
#
# libllvm21-21.1.8     | 42.3 MB   | ##################################5   |  93%
#
#
#
#
#
#
# pyqt-5.15.9          | 5.0 MB    | ##########9                           |  30%
# pillow-10.4.0        | 40.3 MB   | ##########6                           |  29%
#
# scipy-1.10.1         | 22.4 MB   | #############################         |  79%
#
#
#
#
#
# libllvm21-21.1.8     | 42.3 MB   | ###################################2  |  95%
#
#
#
#
#
#
# pyqt-5.15.9          | 5.0 MB    | #################4                    |  47%
# pillow-10.4.0        | 40.3 MB   | ###########4                          |  31%
#
#
#
#
#
# matplotlib-base-3.7. | 6.4 MB    | ###################4                  |  53%
#
# libllvm21-21.1.8     | 42.3 MB   | ###################################8  |  97%
#
#
#
#
#
#
# pyqt-5.15.9          | 5.0 MB    | #######################6              |  64%
# pillow-10.4.0        | 40.3 MB   | ############4                         |  34%
#
#
#
#
#
# matplotlib-base-3.7. | 6.4 MB    | ########################6             |  67%
# libllvm21-21.1.8     | 42.3 MB   | ####################################6 |  99%
#
#
#
#
#
#
# pyqt-5.15.9          | 5.0 MB    | ##############################7       |  83%
#
#
#
#
#
# matplotlib-base-3.7. | 6.4 MB    | ############################8         |  78%
# pillow-10.4.0        | 40.3 MB   | #############2                        |  36%
#
# scipy-1.10.1         | 22.4 MB   | ################################6     |  88%
#
#
#
#
#
#
# pyqt-5.15.9          | 5.0 MB    | ##################################### | 100%
#
#
#
#
#
# matplotlib-base-3.7. | 6.4 MB    | #################################4    |  90%
#
# scipy-1.10.1         | 22.4 MB   | ##################################1   |  92%
# pillow-10.4.0        | 40.3 MB   | ##############                        |  38%
#
# scipy-1.10.1         | 22.4 MB   | ###################################7  |  97%
# pillow-10.4.0        | 40.3 MB   | ##############8                       |  40%
# pillow-10.4.0        | 40.3 MB   | ###############6                      |  42%
# pillow-10.4.0        | 40.3 MB   | ################8                     |  46%
# pillow-10.4.0        | 40.3 MB   | #################9                    |  49%
#
#
#
#
#
#
# pyqt-5.15.9          | 5.0 MB    | ##################################### | 100%
# pillow-10.4.0        | 40.3 MB   | ###################                   |  52%
#
#
#
#
#
#
#
# libglib-2.86.3       | 3.8 MB    | 1                                     |   0%
#
#
#
#
#
#
#
# libglib-2.86.3       | 3.8 MB    | #######3                              |  20%
# pillow-10.4.0        | 40.3 MB   | ####################1                 |  54%
#
#
#
#
#
#
#
# libglib-2.86.3       | 3.8 MB    | #################2                    |  46%
#
#
#
#
#
# matplotlib-base-3.7. | 6.4 MB    | ##################################### | 100%
# pillow-10.4.0        | 40.3 MB   | #####################                 |  57%
#
#
#
#
#
#
#
# libglib-2.86.3       | 3.8 MB    | ############################2         |  76%
# pillow-10.4.0        | 40.3 MB   | ######################1               |  60%
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 2.7 MB    | 2                                     |   1%
# pillow-10.4.0        | 40.3 MB   | #######################1              |  63%
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 2.7 MB    | ##################5                   |  50%
# pillow-10.4.0        | 40.3 MB   | ########################4             |  66%
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 2.7 MB    | ##################################7   |  94%
#
#
#
#
#
#
#
# libglib-2.86.3       | 3.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# libglib-2.86.3       | 3.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libpq-18.1           | 2.6 MB    | 2                                     |   1%
# pillow-10.4.0        | 40.3 MB   | #########################4            |  69%
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 2.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libpq-18.1           | 2.6 MB    | ###############4                      |  42%
# pillow-10.4.0        | 40.3 MB   | ##########################5           |  72%
#
#
#
#
#
#
#
#
#
# libpq-18.1           | 2.6 MB    | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
# fonttools-4.53.1     | 2.2 MB    | 2                                     |   1%
# pillow-10.4.0        | 40.3 MB   | ###########################5          |  74%
#
#
#
#
#
#
#
#
#
#
# fonttools-4.53.1     | 2.2 MB    | ###############2                      |  41%
#
# scipy-1.10.1         | 22.4 MB   | ##################################### | 100%
# pillow-10.4.0        | 40.3 MB   | ############################4         |  77%
#
#
#
#
#
#
#
#
#
#
# fonttools-4.53.1     | 2.2 MB    | ##########################            |  70%
# pillow-10.4.0        | 40.3 MB   | #############################3        |  79%
#
#
#
#
#
#
#
#
#
# libpq-18.1           | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# nss-3.118            | 2.0 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.13   | 820 KB    | 7                                     |   2%
# pillow-10.4.0        | 40.3 MB   | ##############################1       |  82%
#
#
#
#
#
#
#
#
#
#
#
# nss-3.118            | 2.0 MB    | ##############7                       |  40%
#
#
#
#
#
#
#
#
#
#
# fonttools-4.53.1     | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# fonttools-4.53.1     | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.13   | 820 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.13   | 820 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# nss-3.118            | 2.0 MB    | ###############################2      |  84%
# pillow-10.4.0        | 40.3 MB   | ###############################1      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pulseaudio-client-17 | 733 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxkbcommon-1.13.1  | 818 KB    | 7                                     |   2%
# pillow-10.4.0        | 40.3 MB   | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pulseaudio-client-17 | 733 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pulseaudio-client-17 | 733 KB    | ##################################### | 100%
# pillow-10.4.0        | 40.3 MB   | ################################8     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxkbcommon-1.13.1  | 818 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxkbcommon-1.13.1  | 818 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# nss-3.118            | 2.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.19.0     | 671 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.86.3          | 598 KB    | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.4.1        | 627 KB    | 9                                     |   3%
# pillow-10.4.0        | 40.3 MB   | #################################8    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.86.3          | 598 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.86.3          | 598 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.19.0     | 671 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.19.0     | 671 KB    | ##################################### | 100%
# pillow-10.4.0        | 40.3 MB   | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.4.1        | 627 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.4.1        | 627 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsystemd0-259.1    | 511 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# alsa-lib-1.2.15.3    | 571 KB    | #                                     |   3%
# pillow-10.4.0        | 40.3 MB   | ####################################1 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsystemd0-259.1    | 511 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 477 KB    | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# alsa-lib-1.2.15.3    | 571 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 477 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.18.0       | 452 KB    | #3                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm21-21.1.8     | 42.3 MB   | ##################################### | 100%
#
#
#
#
# libclang13-21.1.8    | 11.8 MB   | ##################################### | 100%
# pillow-10.4.0        | 40.3 MB   | ##################################### | 100%
#
#
# libclang-cpp21.1-21. | 20.1 MB   | ##################################### | 100%
#
#
#
#
#
#
# pyqt-5.15.9          | 5.0 MB    | ##################################### | 100%
#
#
#
#
#
# matplotlib-base-3.7. | 6.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 2.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# libglib-2.86.3       | 3.8 MB    | ##################################### | 100%
#
#
#
# pandas-2.0.3         | 11.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libpq-18.1           | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# fonttools-4.53.1     | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.13   | 820 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxkbcommon-1.13.1  | 818 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pulseaudio-client-17 | 733 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# nss-3.118            | 2.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.86.3          | 598 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.19.0     | 671 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsystemd0-259.1    | 511 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsystemd0-259.1    | 511 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.4.1        | 627 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# alsa-lib-1.2.15.3    | 571 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# alsa-lib-1.2.15.3    | 571 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.18.0       | 452 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.18.0       | 452 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 477 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 477 KB    | ##################################### | 100%
#
# libllvm21-21.1.8     | 42.3 MB   | ##################################### | 100%
# pillow-10.4.0        | 40.3 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
